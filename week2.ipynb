# %% [markdown]
# <a href="https://colab.research.google.com/github/haidaroktafiansyah/PCVK_Genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#praktikum 1

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow 
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np 
img = cv.imread('/content/drive/MyDrive/Uyey.png')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
#Tugas 1

plt.figure(figsize=(3,3))
plt.imshow(img3)

# %%
#Tugas 2

img4 = img3
#Red - Green
img4[:,:,0] = np.zeros([img4.shape[0], img4.shape[1]])
plt.imshow(img4)

# %%
#Blue - Green
img5 = img3

img5[:,:,2] = np.zeros([img5.shape[0], img5.shape[1]])
plt.imshow(img5)

# %%
#Tugas 3

img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
#Tugas 4

plt.imshow(img5[5:30])

# %%
#Tugas 5
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(6):
  startp = random.randint(0,400)
  endp = random.randint(0,400)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 2
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %%
#Tugas 6

img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

plt.imshow(img7)

# %%
# Praktium 2

img_gray = cv.imread('/content/drive/MyDrive/Uyey.png', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan FiLe image #cv.imwrite('/content/drive/AyDrive/PCVK MMVImages/mandriLL2.tiff',img5) 
#tampiLkan pLot dengan ukuran canvas yg Lebih besar 
fig = plt.figure(figsize = (10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan 
ax = fig.add_subplot(111) 
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

#perhatikan koordinat titik-titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img) 

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#tugas 1 & 2


img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)


fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(img5,pt1=(100,50),pt2=(250,280),color=(0,255,0), thickness=2)

cv.circle(img5,center=(180,180),radius=100,color=(255,0,0),thickness=2)

cv.rectangle(img5,pt1=(10,530),pt2=(180,590),color=(0,255,0), thickness=2)
cv.putText(img5, text='UWU',org=(20,580),fontFace=font,fontScale=2,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)

ax.imshow(img5)

# %%
Pertanyaan

1 . Apakah perbedaan gambar yang ditampilkan dengan dan tanpa matplotlib ?
=
perbedaanya adalah jika menggunakan matplotlib kita sudah disuguhkan gambar kita yang sudah ada ukuran panjang dan lebarnya 



2 . Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
=
perbedaannya ada pengaruh ukuran file gambar, yang dimana int16 memiliki kapasitas file lebih sedikit ketimbang int32



3 . Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut image.png
=
untuk menampilkan gambar pada google collab, kita perlu menggunakan pacthes



4 . Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
=
untuk men-load gambar, read dan write gambar
